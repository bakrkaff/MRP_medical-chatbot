# %%
import torch
from torch.utils.data import DataLoader, Dataset
import pandas as pd
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, AdamW
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import numpy as np

# %%
# Load the dataset
data = pd.read_csv('medquad.csv')
data.dropna(subset=['focus_area'], inplace=True)

# Basic text preprocessing
data['processed_question'] = data['question'].apply(lambda x: x.lower())

# %%
# Split the dataset
train_texts, val_texts, train_labels, val_labels = train_test_split(
    data['processed_question'], data['focus_area'], test_size=0.1, random_state=42)

# %%
# Initialize the tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

# Encode the text data for DistilBERT
# Define text encoding function
# Function to encode texts
def encode_texts(texts):
    return tokenizer(texts.tolist(), padding=True, truncation=True, max_length=128, return_tensors='pt')

train_encodings = encode_texts(train_texts)
val_encodings = encode_texts(val_texts)

# %%
# Create label dictionary and encode labels
label_dict = {label: idx for idx, label in enumerate(pd.unique(data['focus_area']))}
train_labels_encoded = [label_dict[label] for label in train_labels]
val_labels_encoded = [label_dict[label] for label in val_labels]

# Dataset class
class TextDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
# Create data loaders
train_dataset = TextDataset(train_encodings, train_labels_encoded)
val_dataset = TextDataset(val_encodings, val_labels_encoded)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
# Load DistilBERT model for sequence classification
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=len(label_dict))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=5126, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# Define optimizer
optimizer = AdamW(model.parameters(), lr=5e-5)

# Training and evaluation functions (simplified for brevity)
def train(model, loader, optimizer, device):
    model.train()
    for batch in loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
# Out:
# /opt/conda/envs/python39/lib/python3.9/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
def evaluate(model, loader, device, label_dict):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            preds = torch.argmax(outputs.logits, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Convert numerical labels back to original labels for reporting
    target_names = [k for k, v in sorted(label_dict.items(), key=lambda item: item[1])]
    return classification_report(all_labels, all_preds, target_names=target_names, labels=np.arange(len(label_dict)))

# Update your evaluation call
for epoch in range(3):
    train(model, train_loader, optimizer, device)
    print(f"Epoch {epoch+1} Evaluation:")
    report = evaluate(model, val_loader, device, label_dict)
    print(report)
# Out:
# /var/tmp/ipykernel_451504/3440983983.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Epoch 1 Evaluation:
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /var/tmp/ipykernel_451504/3440983983.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#                                                                                                                                           precision    recall  f1-score   support
#
#                                                                                                                                 Glaucoma       0.67      1.00      0.80         2
#                                                                                                                      High Blood Pressure       1.00      1.00      1.00         3
#                                                                                                                  Paget's Disease of Bone       0.00      0.00      0.00         0
#                                                                                                                 Urinary Tract Infections       0.00      0.00      0.00         3
#                                                                                                             Alcohol Use and Older Adults       0.00      0.00      0.00         0
#                                                                                                                           Osteoarthritis       0.00      0.00      0.00         0
#                                                                                                                      Problems with Taste       0.75      1.00      0.86         3
#                                                                                                                        Anxiety Disorders       0.38      1.00      0.55         3
#                                                                                                                                 Diabetes       0.00      0.00      0.00         0
#                                                                                                             Medicare and Continuing Care       1.00      1.00      1.00         2
#                                                                                                                         Knee Replacement       0.00      0.00      0.00         0
#                                                                                                                         Balance Problems       0.67      1.00      0.80         2
#                                                                                                        Quitting Smoking for Older Adults       0.00      0.00      0.00         0
#                                                                                                                          Prostate Cancer       1.00      1.00      1.00         5
#                                                                                                                                Dry Mouth       1.00      1.00      1.00         2
#                                                                                                                             Osteoporosis       0.00      0.00      0.00         0
#                                                                                                                           Kidney Disease       0.00      0.00      0.00         0
#                                                                                                                      Alzheimer's Disease       0.67      1.00      0.80         2
#                                                                                                                     Rheumatoid Arthritis       0.33      1.00      0.50         2
#                                                                                                                             Hearing Loss       0.80      1.00      0.89         4
#                                                                                                                               Low Vision       0.00      0.00      0.00         0
#                                                                                                                                     COPD       1.00      1.00      1.00         1
#                                                                                                         Age-related Macular Degeneration       0.25      1.00      0.40         1
#                                                                                                                     Diabetic Retinopathy       0.60      1.00      0.75         3
#                                                                                                                               Depression       1.00      1.00      1.00         1
#                                                                                                                      Problems with Smell       0.67      1.00      0.80         2
#                                                                                                                            Breast Cancer       0.50      1.00      0.67         3
#                                                                                                                        Colorectal Cancer       1.00      1.00      1.00         6
#                                                                                                                      Parkinson's Disease       0.40      1.00      0.57         2
#                                                                                                                                 Leukemia       0.75      1.00      0.86         3
#                                                                                                                              Lung Cancer       0.50      1.00      0.67         5
#                                                                                                                     Urinary Incontinence       0.00      0.00      0.00         0
#                                                                                                                                   Stroke       1.00      1.00      1.00         5
#                                                                                                                                Psoriasis       1.00      1.00      1.00         2
#                                                                                                                   High Blood Cholesterol       1.00      1.00      1.00         2
#                                                                                                     Peripheral Arterial Disease (P.A.D.)       0.00      0.00      0.00         0
#                                                                                                      Prescription and Illicit Drug Abuse       0.00      0.00      0.00         0
#                                                                                                                                 Cataract       0.00      0.00      0.00         0
#                                                                                                         Creating a Family Health History       0.00      0.00      0.00         0
#                                                                                                                                 Shingles       1.00      1.00      1.00         2
#                                                                                                                             Heart Attack       0.40      1.00      0.57         2
#                                                                                                                              Skin Cancer       1.00      1.00      1.00         2
#                                                                                                                         Surviving Cancer       0.00      0.00      0.00         0
#                                                                                                                                     Gout       1.00      1.00      1.00         2
#                                                                                                                   Alzheimer's Caregiving       1.00      1.00      1.00         1
#                                                                                                                                  Dry Eye       0.67      1.00      0.80         2
#                                                                                                                Gum (Periodontal) Disease       0.75      1.00      0.86         3
#                                                                                                                            Heart Failure       0.83      1.00      0.91         5
#                                                                                                                      Hairy Cell Leukemia       0.00      0.00      0.00         0
#                                                                                                                            Vulvar Cancer       0.00      0.00      0.00         0
#                                                                                                                       Gallbladder Cancer       1.00      1.00      1.00         1
#                                                                                                    Atypical Chronic Myelogenous Leukemia       0.00      0.00      0.00         0
#                                                                                            Myelodysplastic/ Myeloproliferative Neoplasms       0.00      0.00      0.00         0
#                                                                                                             Adult Acute Myeloid Leukemia       0.00      0.00      0.00         0
#                                                                                                            Childhood Soft Tissue Sarcoma       0.00      0.00      0.00         0
#                                                                                                             Thymoma and Thymic Carcinoma       1.00      1.00      1.00         1
#                                                                                            Wilms Tumor and Other Childhood Kidney Tumors       1.00      1.00      1.00         1
#                                                                                                                              Anal Cancer       0.00      0.00      0.00         0
#                                                                                                  Childhood Extracranial Germ Cell Tumors       0.40      1.00      0.57         2
#                                                                                                                          Uterine Sarcoma       1.00      1.00      1.00         1
#                                                                                                                        Polycythemia Vera       0.60      1.00      0.75         3
#                                                                                                             Chronic Myelogenous Leukemia       0.00      0.00      0.00         0
#                                                                                                                    Merkel Cell Carcinoma       1.00      1.00      1.00         1
#                                                                                                            Extragonadal Germ Cell Tumors       1.00      1.00      1.00         1
#                                                                                                                        Renal Cell Cancer       0.00      0.00      0.00         2
#                                                                                                            Chronic Neutrophilic Leukemia       0.00      0.00      0.00         1
#                                                                                                                   Small Cell Lung Cancer       0.00      0.00      0.00         1
#                                                                                                   Ovarian Low Malignant Potential Tumors       0.00      0.00      0.00         0
#                                                                                                            Chronic Eosinophilic Leukemia       0.00      0.00      0.00         0
#                                                                                   Ovarian, Fallopian Tube, and Primary Peritoneal Cancer       0.00      0.00      0.00         0
#                                                                                                                             Colon Cancer       1.00      1.00      1.00         2
#                                                                                                            Liver (Hepatocellular) Cancer       0.50      1.00      0.67         1
#                                                                                                                        Testicular Cancer       1.00      1.00      1.00         1
#                                                                                                             Intraocular (Uveal) Melanoma       0.00      0.00      0.00         0
#                                                                                                                    Hypopharyngeal Cancer       0.00      0.00      0.00         0
#                                                                             Myelodysplastic/ Myeloproliferative Neoplasm, Unclassifiable       0.00      0.00      0.00         0
#                                                                                                                            Rectal Cancer       0.00      0.00      0.00         0
#                                                                                                                Myelodysplastic Syndromes       0.00      0.00      0.00         0
#                                                                                                                   Childhood Astrocytomas       1.00      1.00      1.00         1
#                                                                                      Metastatic Squamous Neck Cancer with Occult Primary       0.00      0.00      0.00         0
#                                                                                                                   Small Intestine Cancer       0.00      0.00      0.00         0
#                                                                          Childhood Acute Myeloid Leukemia and Other Myeloid Malignancies       0.00      0.00      0.00         0
#                                                                                                               Non-Small Cell Lung Cancer       0.00      0.00      0.00         2
#                                                                                                         Juvenile Myelomonocytic Leukemia       0.00      0.00      0.00         2
#                                                                                                                Childhood Vascular Tumors       0.00      0.00      0.00         0
#                                                                                                              Childhood Brain Stem Glioma       0.33      1.00      0.50         1
#                                                                                  Transitional Cell Cancer of the Renal Pelvis and Ureter       1.00      1.00      1.00         1
#                                                                                                        Gestational Trophoblastic Disease       1.00      1.00      1.00         2
#                                                                        Ovarian Epithelial, Fallopian Tube, and Primary Peritoneal Cancer       0.12      1.00      0.22         1
#                                                                                                     Oral Cavity and Oropharyngeal Cancer       0.00      0.00      0.00         0
#                                                                                                                       Endometrial Cancer       0.25      1.00      0.40         1
#                                                                                                                    AIDS-Related Lymphoma       0.00      0.00      0.00         0
#                                                                                                                        Pancreatic Cancer       0.50      1.00      0.67         1
#                                                                                                    Bile Duct Cancer (Cholangiocarcinoma)       1.00      1.00      1.00         1
#                                                                                     Pancreatic Neuroendocrine Tumors (Islet Cell Tumors)       0.00      0.00      0.00         3
#                                                                                                                         Laryngeal Cancer       0.00      0.00      0.00         0
#                                                                                       Plasma Cell Neoplasms (Including Multiple Myeloma)       0.00      0.00      0.00         0
#                                                                                                                    Salivary Gland Cancer       0.67      1.00      0.80         2
#                                                                                                           Childhood Non-Hodgkin Lymphoma       0.00      0.00      0.00         0
#                                                                                                        Gastrointestinal Carcinoid Tumors       0.00      0.00      0.00         0
#                                                                                                                Adult Soft Tissue Sarcoma       0.00      0.00      0.00         0
#                                                                                                                     Primary CNS Lymphoma       0.00      0.00      0.00         0
#                                                                                                                       Parasitic Diseases       0.00      0.00      0.00         0
#                                                                                                                   Coronavirus Infections       0.00      0.00      0.00         0
#                                                                                                                       Pulmonary Fibrosis       0.00      0.00      0.00         0
#                                                                                                                         Impaired Driving       0.00      0.00      0.00         0
#                                                                                                                             Sun Exposure       0.00      0.00      0.00         0
#                                                                                                                  Pregnancy and Medicines       0.00      0.00      0.00         0
#                                                                                                                          Metabolic Panel       0.00      0.00      0.00         0
#                                                                                                                          Aplastic Anemia       1.00      1.00      1.00         1
# ...
#                                                                                                                          Biliary Atresia       0.00      0.00      0.00         0
#                                                                                                                                Gastritis       0.67      1.00      0.80         2
#                                                                     What I need to know about Preparing for Pregnancy if I Have Diabetes       0.00      0.00      0.00         0
#                                                                                                                       Fecal Incontinence       0.50      1.00      0.67         1
#                                                                                                                      Abdominal Adhesions       0.25      1.00      0.40         1
#                                                                                                                Polycystic Kidney Disease       0.50      1.00      0.67         1
#                                                                             What I need to know about Kidney Failure and How Its Treated       1.00      1.00      1.00         1
#                                                                                                                 Perineal Injury in Males       0.00      0.00      0.00         0
#                                                                                                                           Ectopic Kidney       0.00      0.00      0.00         0
#                                                                                                      Multiple Endocrine Neoplasia Type 1       0.00      0.00      0.00         0
#                                                                                                           Hematuria (Blood in the Urine)       0.00      0.00      0.00         0
#                                                                                                               Urine Blockage in Newborns       0.00      0.00      0.00         0
#                                                                                      What I need to know about Bladder Control for Women       0.00      0.00      0.00         0
#                                                                                                                      Glomerular Diseases       0.00      0.00      0.00         0
#                                                    Am I at Risk for Type 2 Diabetes? Taking Steps to Lower Your Risk of Getting Diabetes       0.00      0.00      0.00         0
#                                                                                                       Insulin Resistance and Prediabetes       1.00      1.00      1.00         1
#                                                                    I Can Lower My Risk for Type 2 Diabetes: A Guide for American Indians       0.00      0.00      0.00         0
#                                                                                                                    Renal Artery Stenosis       1.00      1.00      1.00         2
#                                                                                                           Amyloidosis and Kidney Disease       0.00      0.00      0.00         0
#                                                                                                                Primary Biliary Cirrhosis       1.00      1.00      1.00         1
#                                                                                                                              Proteinuria       1.00      1.00      1.00         1
#                                                                                       Prostate Enlargement: Benign Prostatic Hyperplasia       1.00      1.00      1.00         3
#                                                                                                                         Dumping Syndrome       1.00      1.00      1.00         1
#                                                                                                                   Renal Tubular Acidosis       1.00      1.00      1.00         1
#                                                                                                                         Kidney Dysplasia       1.00      1.00      1.00         2
#                                                                                                                    Viral Gastroenteritis       1.00      1.00      1.00         1
#                                                                                       Prevent diabetes problems: Keep your mouth healthy       0.00      0.00      0.00         0
#                                                                                     Nutrition for Early Chronic Kidney Disease in Adults       1.00      1.00      1.00         1
#                                                                                                    Diagnosis of Diabetes and Prediabetes       0.00      0.00      0.00         0
#                                                                                                        Nerve Disease and Bladder Control       0.00      0.00      0.00         0
#                                                                                                           Kidney Failure: What to Expect       0.00      0.00      0.00         0
#                                                                                                    What I need to know about Hepatitis A       0.50      1.00      0.67         1
#                                                                              Prevent diabetes problems: Keep your diabetes under control       1.00      1.00      1.00         1
#                                                                                                    What I need to know about Hepatitis C       1.00      1.00      1.00         1
# National Hormone and Pituitary Program (NHPP): Information for People Treated with Pituitary Human Growth Hormone (Comprehensive Report)       1.00      1.00      1.00         3
#                                                                                                   High Blood Pressure and Kidney Disease       0.00      0.00      0.00         0
#                                                                                                                     Goodpasture Syndrome       0.00      0.00      0.00         0
#                                                                                        Prevent diabetes problems: Keep your eyes healthy       0.00      0.00      0.00         0
#                                                                                                     Urinary Tract Infections in Children       0.67      1.00      0.80         2
#                                                                              Facing the Challenges of Chronic Kidney Disease in Children       0.00      0.00      0.00         0
#                                                                                                                      Foodborne Illnesses       0.25      1.00      0.40         4
#                                                                                                                  Medullary Sponge Kidney       1.00      1.00      1.00         1
#                                                                                                                          Lupus Nephritis       0.00      0.00      0.00         0
#                                                                 What I need to know about Interstitial Cystitis/Painful Bladder Syndrome       0.00      0.00      0.00         0
#                                                                                           What I need to know about Gestational Diabetes       1.00      1.00      1.00         1
#                                           Dermatitis Herpetiformis: Skin Manifestation of Celiac Disease (For Health Care Professionals)       0.00      0.00      0.00         0
#                                                                                                Your Guide to Diabetes: Type 1 and Type 2       0.00      0.00      0.00         0
#                                                                                                        Urinary Tract Infection In Adults       0.00      0.00      0.00         0
#                                                                                                            Pregnancy and Thyroid Disease       0.50      1.00      0.67         1
#                                                                                                What I need to know about Crohn's Disease       0.00      0.00      0.00         0
#                                                                                                             Chronic Diarrhea in Children       1.00      1.00      1.00         2
#                                                                                                         Anemia in Chronic Kidney Disease       1.00      1.00      1.00         3
#                                                                                                                    Vesicoureteral Reflux       0.00      0.00      0.00         0
#                                                                                                                  Diabetic Kidney Disease       1.00      1.00      1.00         3
#                                                                                                    Hemolytic Uremic Syndrome in Children       0.57      1.00      0.73         4
#                                                                                                               Zollinger-Ellison Syndrome       1.00      1.00      1.00         1
#                                                                                                                                Cystocele       1.00      1.00      1.00         1
#                                                                                                                          Inguinal Hernia       0.00      0.00      0.00         0
#                                                                                     What I need to know about Living with Kidney Failure       0.00      0.00      0.00         0
#                                                                                                       What I need to know about Diarrhea       0.00      0.00      0.00         0
#                                                                                                  Viral Hepatitis: A through E and Beyond       0.00      0.00      0.00         0
#                                                                                                             Nonalcoholic Steatohepatitis       0.50      1.00      0.67         2
#                                                                                                               Your Diabetes Care Records       0.00      0.00      0.00         0
#                                                                                                                  Henoch-Schnlein Purpura       0.00      0.00      0.00         0
#                                                                                                             Childhood Nephrotic Syndrome       1.00      1.00      1.00         2
#                                                                                                                         Mntriers Disease       1.00      1.00      1.00         1
#                                                                                                                     Diverticular Disease       1.00      1.00      1.00         3
#                                                                         Microscopic Colitis: Collagenous Colitis and Lymphocytic Colitis       0.00      0.00      0.00         0
#                                                                                                                 Cyclic Vomiting Syndrome       0.00      0.00      0.00         0
#                                                                                      Diabetic Neuropathies: The Nerve Damage of Diabetes       0.00      0.00      0.00         0
#
#                                                                                                                                 accuracy                           0.66      1640
#                                                                                                                                macro avg       0.15      0.16      0.15      1640
#                                                                                                                             weighted avg       0.62      0.66      0.63      1640
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/python39/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
