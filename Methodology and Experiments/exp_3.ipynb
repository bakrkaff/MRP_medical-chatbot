# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pandas as pd
import numpy as np
from torchtext.vocab import build_vocab_from_iterator
from torchtext.data.utils import get_tokenizer

# %%
# Load and preprocess the dataset
data = pd.read_csv('medquad.csv')
data.dropna(subset=['focus_area'], inplace=True)
data['processed_question'] = data['question'].apply(lambda x: x.lower())

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Tokenization
tokenizer = get_tokenizer('basic_english')
def yield_tokens(data_iter):
    for text in data_iter:
        yield tokenizer(text)
vocab = build_vocab_from_iterator(yield_tokens(data['processed_question']), specials=["<unk>"])
vocab.set_default_index(vocab["<unk>"])

# Encoding texts
def encode_text(text, vocab, tokenizer):
    return [vocab[token] for token in tokenizer(text)]

# %%
data['encoded'] = data['processed_question'].apply(lambda x: encode_text(x, vocab, tokenizer))

# Prepare labels
label_dict = {label: idx for idx, label in enumerate(pd.unique(data['focus_area']))}
data['labels'] = data['focus_area'].map(label_dict)

# %%
# Data Augmentation: Oversample minority classes
def oversample_data(data):
    max_size = data['labels'].value_counts().max()
    lst = [data]
    for class_index, group in data.groupby('labels'):
        lst.append(group.sample(max_size - len(group), replace=True))
    data_balanced = pd.concat(lst)
    return data_balanced

data = oversample_data(data)

# Split data
train_data, val_data = train_test_split(data, test_size=0.1, random_state=42)

# %%
# Dataset class
class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels

    def __getitem__(self, idx):
        return torch.tensor(self.texts[idx], dtype=torch.long), self.labels[idx]

    def __len__(self):
        return len(self.labels)

# %%
# Collate function to handle padding
def collate_batch(batch):
    label_list, text_list = [], []
    for _text, _label in batch:
        label_list.append(_label)
        if isinstance(_text, torch.Tensor):
            text_list.append(_text.clone().detach())  # Use clone to avoid the warning
        else:
            text_list.append(torch.tensor(_text, dtype=torch.long))  # Convert list to tensor if not already
    text_list = pad_sequence(text_list, batch_first=True, padding_value=0)
    label_list = torch.tensor(label_list, dtype=torch.long)
    return text_list, label_list

# %%
train_dataset = TextDataset(list(train_data['encoded']), list(train_data['labels']))
val_dataset = TextDataset(list(val_data['encoded']), list(val_data['labels']))

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, collate_fn=collate_batch)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, collate_fn=collate_batch)

# %%
# Define the LSTM with Attention model
class Attention(nn.Module):
    def __init__(self, hidden_dim):
        super(Attention, self).__init__()
        self.hidden_dim = hidden_dim
        self.main = nn.Sequential(
            nn.Linear(hidden_dim, 64),
            nn.ReLU(True),
            nn.Linear(64, 1)
        )

    def forward(self, lstm_output, final_state):
        attn_weights = self.main(lstm_output)
        soft_attn_weights = F.softmax(attn_weights, 1)
        new_hidden_state = torch.bmm(lstm_output.transpose(1, 2), soft_attn_weights).squeeze(2)
        return new_hidden_state

# %%
class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes):
        super(LSTMClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.attention = Attention(hidden_dim)
        self.fc = nn.Linear(hidden_dim, num_classes)

    def forward(self, text):
        embedded = self.embedding(text)
        lstm_out, (hidden, cell) = self.lstm(embedded)
        attn_out = self.attention(lstm_out, hidden)
        return self.fc(attn_out)

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.logits = logits
        self.reduce = reduce

    def forward(self, inputs, targets):
        if self.logits:
            BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduce=False)
        else:
            BCE_loss = F.binary_cross_entropy(inputs, targets, reduce=False)
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss

# %%
# Initialize model, loss, and optimizer
num_classes = 5126
model = LSTMClassifier(len(vocab), 100, 128, num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Training and evaluation functions
def train(model, iterator, optimizer, criterion, device):
    model.train()
    epoch_loss = 0
    for texts, labels in iterator:
        texts, labels = texts.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    return epoch_loss / len(iterator)

def evaluate(model, iterator, criterion, device):
    model.eval()
    epoch_loss = 0
    predictions, true_labels = [], []
    with torch.no_grad():
        for texts, labels in iterator:
            texts, labels = texts.to(device), labels.to(device)
            outputs = model(texts)
            loss = criterion(outputs, labels)
            epoch_loss += loss.item()
            preds = outputs.argmax(dim=1)
            predictions.extend(preds.tolist())
            true_labels.extend(labels.tolist())

    # Ensure all classes are included in the classification report
    all_labels = list(label_dict.values())
    report = classification_report(true_labels, predictions, labels=all_labels, target_names=list(label_dict.keys()))
    return epoch_loss / len(iterator), report

# %%
# Training loop
num_epochs = 3
for epoch in range(num_epochs):
    train_loss = train(model, train_loader, optimizer, criterion, device)
    val_loss, report = evaluate(model, val_loader, criterion, device)
    print(f'Epoch: {epoch+1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
    print(report)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch: 1, Train Loss: 0.1044, Val Loss: 0.0958
#                                                                                                                                           precision    recall  f1-score   support
#
#                                                                                                                                 Glaucoma       1.00      1.00      1.00        13
#                                                                                                                      High Blood Pressure       1.00      1.00      1.00         4
#                                                                                                                  Paget's Disease of Bone       1.00      1.00      1.00         5
#                                                                                                                 Urinary Tract Infections       1.00      1.00      1.00         3
#                                                                                                             Alcohol Use and Older Adults       1.00      1.00      1.00         3
#                                                                                                                           Osteoarthritis       1.00      1.00      1.00         9
#                                                                                                                      Problems with Taste       1.00      1.00      1.00        10
#                                                                                                                        Anxiety Disorders       1.00      1.00      1.00         3
#                                                                                                                                 Diabetes       1.00      1.00      1.00         8
#                                                                                                             Medicare and Continuing Care       1.00      1.00      1.00         4
#                                                                                                                         Knee Replacement       1.00      1.00      1.00         5
#                                                                                                                         Balance Problems       1.00      1.00      1.00         3
#                                                                                                        Quitting Smoking for Older Adults       1.00      1.00      1.00         4
#                                                                                                                          Prostate Cancer       1.00      0.50      0.67         2
#                                                                                                                                Dry Mouth       1.00      1.00      1.00         7
#                                                                                                                             Osteoporosis       1.00      1.00      1.00         5
#                                                                                                                           Kidney Disease       1.00      1.00      1.00         8
#                                                                                                                      Alzheimer's Disease       1.00      1.00      1.00         4
#                                                                                                                     Rheumatoid Arthritis       1.00      0.25      0.40         8
#                                                                                                                             Hearing Loss       1.00      1.00      1.00        10
#                                                                                                                               Low Vision       1.00      1.00      1.00         3
#                                                                                                                                     COPD       1.00      1.00      1.00         5
#                                                                                                         Age-related Macular Degeneration       0.50      1.00      0.67         3
#                                                                                                                     Diabetic Retinopathy       1.00      1.00      1.00         4
#                                                                                                                               Depression       1.00      1.00      1.00         7
#                                                                                                                      Problems with Smell       1.00      1.00      1.00         6
#                                                                                                                            Breast Cancer       1.00      0.71      0.83         7
#                                                                                                                        Colorectal Cancer       1.00      1.00      1.00         2
#                                                                                                                      Parkinson's Disease       1.00      1.00      1.00         5
#                                                                                                                                 Leukemia       1.00      1.00      1.00         7
#                                                                                                                              Lung Cancer       1.00      0.14      0.25         7
#                                                                                                                     Urinary Incontinence       1.00      1.00      1.00        10
#                                                                                                                                   Stroke       1.00      1.00      1.00         6
#                                                                                                                                Psoriasis       1.00      1.00      1.00         1
#                                                                                                                   High Blood Cholesterol       1.00      1.00      1.00         4
#                                                                                                     Peripheral Arterial Disease (P.A.D.)       1.00      1.00      1.00         5
#                                                                                                      Prescription and Illicit Drug Abuse       1.00      1.00      1.00         9
#                                                                                                                                 Cataract       0.00      0.00      0.00         0
#                                                                                                         Creating a Family Health History       1.00      1.00      1.00         3
#                                                                                                                                 Shingles       1.00      1.00      1.00         8
#                                                                                                                             Heart Attack       1.00      1.00      1.00         3
#                                                                                                                              Skin Cancer       1.00      1.00      1.00         5
#                                                                                                                         Surviving Cancer       1.00      1.00      1.00         9
#                                                                                                                                     Gout       1.00      1.00      1.00         5
#                                                                                                                   Alzheimer's Caregiving       1.00      1.00      1.00         7
#                                                                                                                                  Dry Eye       1.00      1.00      1.00         4
#                                                                                                                Gum (Periodontal) Disease       1.00      1.00      1.00         8
#                                                                                                                            Heart Failure       1.00      1.00      1.00         2
#                                                                                                                      Hairy Cell Leukemia       0.67      1.00      0.80         2
#                                                                                                                            Vulvar Cancer       1.00      1.00      1.00         4
#                                                                                                                       Gallbladder Cancer       1.00      1.00      1.00         8
#                                                                                                    Atypical Chronic Myelogenous Leukemia       1.00      1.00      1.00         2
#                                                                                            Myelodysplastic/ Myeloproliferative Neoplasms       1.00      1.00      1.00         2
#                                                                                                             Adult Acute Myeloid Leukemia       0.00      0.00      0.00         0
#                                                                                                            Childhood Soft Tissue Sarcoma       1.00      1.00      1.00         5
#                                                                                                             Thymoma and Thymic Carcinoma       1.00      1.00      1.00         6
#                                                                                            Wilms Tumor and Other Childhood Kidney Tumors       1.00      1.00      1.00         2
#                                                                                                                              Anal Cancer       1.00      1.00      1.00         3
#                                                                                                  Childhood Extracranial Germ Cell Tumors       1.00      1.00      1.00        13
#                                                                                                                          Uterine Sarcoma       1.00      1.00      1.00         8
#                                                                                                                        Polycythemia Vera       0.80      0.67      0.73         6
#                                                                                                             Chronic Myelogenous Leukemia       1.00      1.00      1.00         4
#                                                                                                                    Merkel Cell Carcinoma       1.00      1.00      1.00         6
#                                                                                                            Extragonadal Germ Cell Tumors       1.00      1.00      1.00         4
#                                                                                                                        Renal Cell Cancer       1.00      1.00      1.00         5
#                                                                                                            Chronic Neutrophilic Leukemia       1.00      1.00      1.00         1
#                                                                                                                   Small Cell Lung Cancer       1.00      1.00      1.00         4
#                                                                                                   Ovarian Low Malignant Potential Tumors       1.00      1.00      1.00         5
#                                                                                                            Chronic Eosinophilic Leukemia       1.00      1.00      1.00         5
#                                                                                   Ovarian, Fallopian Tube, and Primary Peritoneal Cancer       1.00      1.00      1.00        11
#                                                                                                                             Colon Cancer       1.00      1.00      1.00         4
#                                                                                                            Liver (Hepatocellular) Cancer       1.00      1.00      1.00         6
#                                                                                                                        Testicular Cancer       1.00      1.00      1.00         5
#                                                                                                             Intraocular (Uveal) Melanoma       1.00      1.00      1.00         4
#                                                                                                                    Hypopharyngeal Cancer       1.00      1.00      1.00         5
#                                                                             Myelodysplastic/ Myeloproliferative Neoplasm, Unclassifiable       1.00      1.00      1.00         6
#                                                                                                                            Rectal Cancer       1.00      1.00      1.00         4
#                                                                                                                Myelodysplastic Syndromes       1.00      0.20      0.33         5
#                                                                                                                   Childhood Astrocytomas       1.00      1.00      1.00         3
#                                                                                      Metastatic Squamous Neck Cancer with Occult Primary       1.00      1.00      1.00         5
#                                                                                                                   Small Intestine Cancer       1.00      1.00      1.00         3
#                                                                          Childhood Acute Myeloid Leukemia and Other Myeloid Malignancies       1.00      1.00      1.00         5
#                                                                                                               Non-Small Cell Lung Cancer       1.00      1.00      1.00         5
#                                                                                                         Juvenile Myelomonocytic Leukemia       1.00      0.67      0.80         3
#                                                                                                                Childhood Vascular Tumors       1.00      1.00      1.00         9
#                                                                                                              Childhood Brain Stem Glioma       1.00      1.00      1.00         6
#                                                                                  Transitional Cell Cancer of the Renal Pelvis and Ureter       1.00      1.00      1.00         5
#                                                                                                        Gestational Trophoblastic Disease       1.00      1.00      1.00         9
#                                                                        Ovarian Epithelial, Fallopian Tube, and Primary Peritoneal Cancer       1.00      1.00      1.00         5
#                                                                                                     Oral Cavity and Oropharyngeal Cancer       1.00      1.00      1.00         9
#                                                                                                                       Endometrial Cancer       1.00      1.00      1.00         4
#                                                                                                                    AIDS-Related Lymphoma       1.00      1.00      1.00         8
#                                                                                                                        Pancreatic Cancer       1.00      1.00      1.00        12
#                                                                                                    Bile Duct Cancer (Cholangiocarcinoma)       1.00      1.00      1.00         3
#                                                                                     Pancreatic Neuroendocrine Tumors (Islet Cell Tumors)       1.00      1.00      1.00         5
#                                                                                                                         Laryngeal Cancer       1.00      1.00      1.00         8
#                                                                                       Plasma Cell Neoplasms (Including Multiple Myeloma)       1.00      1.00      1.00         6
#                                                                                                                    Salivary Gland Cancer       1.00      1.00      1.00         4
#                                                                                                           Childhood Non-Hodgkin Lymphoma       1.00      1.00      1.00         5
#                                                                                                        Gastrointestinal Carcinoid Tumors       1.00      1.00      1.00         5
#                                                                                                                Adult Soft Tissue Sarcoma       1.00      1.00      1.00         4
#                                                                                                                     Primary CNS Lymphoma       1.00      1.00      1.00        10
#                                                                                                                            Neuroblastoma       1.00      1.00      1.00         1
#                                                                                  Osteosarcoma and Malignant Fibrous Histiocytoma of Bone       1.00      1.00      1.00         3
#                                                                                                               Adult Non-Hodgkin Lymphoma       1.00      1.00      1.00         6
#                                                                                                                           Kaposi Sarcoma       1.00      0.67      0.80         6
#                                                                                                             Chronic Lymphocytic Leukemia       1.00      1.00      1.00         4
#                                                                                                      Adult Central Nervous System Tumors       1.00      1.00      1.00         9
#                                                                                                                Essential Thrombocythemia       0.80      1.00      0.89         8
#                                                                                                               Childhood Rhabdomyosarcoma       1.00      1.00      1.00        10
#                                                                                                                         Pituitary Tumors       1.00      1.00      1.00         6
#                                                                                                          Chronic Myelomonocytic Leukemia       1.00      1.00      1.00         1
#                                                                                                                    Nasopharyngeal Cancer       1.00      1.00      1.00         5
#                                                                                                          Gastrointestinal Stromal Tumors       1.00      1.00      1.00         6
#                                                                                                               Adult Primary Liver Cancer       1.00      1.00      1.00         5
#                                                                                        Childhood Central Nervous System Embryonal Tumors       1.00      1.00      1.00         5
#                                                                                                                   Adult Hodgkin Lymphoma       1.00      1.00      1.00         8
#                                                                                                       Adult Acute Lymphoblastic Leukemia       1.00      1.00      1.00         3
#                                                                                                     Chronic Myeloproliferative Neoplasms       1.00      1.00      1.00         4
#                                                                                                                       Parathyroid Cancer       1.00      1.00      1.00         6
#                                                                                                               Lip and Oral Cavity Cancer       1.00      1.00      1.00         5
#                                                                                                              Childhood Craniopharyngioma       1.00      1.00      1.00         8
#                                                                                                                     Childhood Ependymoma       1.00      1.00      1.00         7
#                                                                                        Childhood Central Nervous System Germ Cell Tumors       1.00      1.00      1.00         6
#                                                                                                                 Ovarian Germ Cell Tumors       1.00      1.00      1.00         6
#                                                                                                               Childhood Hodgkin Lymphoma       1.00      1.00      1.00         3
#                                                                                                                            Penile Cancer       1.00      1.00      1.00         4
#                                                                                                                     Oropharyngeal Cancer       1.00      1.00      1.00         3
#                                                                                                                       Male Breast Cancer       1.00      1.00      1.00         7
#                                                                                                                    Primary Myelofibrosis       1.00      0.50      0.67         4
#                                                                                                                          Urethral Cancer       1.00      1.00      1.00         5
#                                                                                                                                 Melanoma       1.00      1.00      1.00         8
#                                                                        Childhood Central Nervous System Atypical Teratoid/Rhabdoid Tumor       1.00      1.00      1.00         9
#                                                                                                                           Retinoblastoma       1.00      0.38      0.55         8
#                                                                                                   Childhood Acute Lymphoblastic Leukemia       1.00      1.00      1.00         2
#                                                                                                                   Childhood Liver Cancer       1.00      1.00      1.00         1
#                                                                                                 Mycosis Fungoides and the Szary Syndrome       1.00      1.00      1.00         6
#                                                                                                                            Ewing Sarcoma       0.50      1.00      0.67         2
#                                                                                                   Childhood Brain and Spinal Cord Tumors       1.00      1.00      1.00         7
#                                                                                                            Langerhans Cell Histiocytosis       1.00      0.75      0.86         4
#                                                                                                  Paranasal Sinus and Nasal Cavity Cancer       1.00      1.00      1.00        11
#                                                                                                                 Campylobacter Infections       1.00      1.00      1.00         5
#                                                                                                            Pregnancy and Substance Abuse       1.00      1.00      1.00         8
#                                                                                                                        Radiation Therapy       1.00      1.00      1.00         3
#                                                                                                                           Rehabilitation       1.00      1.00      1.00         5
#                                                                                                                                     Iron       1.00      1.00      1.00         9
#                                                                                                                  Pregnancy and Nutrition       1.00      1.00      1.00         6
#                                                                                                               Interstitial Lung Diseases       1.00      1.00      1.00         5
#                                                                                                                                Volcanoes       1.00      1.00      1.00         7
#                                                                                                                                  Hiccups       1.00      1.00      1.00         4
#                                                                                                                    Premenstrual Syndrome       1.00      1.00      1.00         3
#                                                                                                                    Dizziness and Vertigo       1.00      1.00      1.00         6
#                                                                                                                           Oxygen Therapy       1.00      1.00      1.00         2
#                                                                                                                     Huntington's Disease       1.00      1.00      1.00         3
#                                                                                                                         Premature Babies       1.00      1.00      1.00         6
#                                                                                                                          Mouth Disorders       1.00      1.00      1.00         1
#                                                                                                          Vision Impairment and Blindness       1.00      1.00      1.00         3
#                                                                                                                                   Tremor       1.00      1.00      1.00         4
#                                                                                                              Nose Injuries and Disorders       1.00      1.00      1.00         5
#                                                                                                                               Diphtheria       1.00      1.00      1.00         7
#                                                                                                                        Esophageal Cancer       1.00      1.00      1.00         7
#                                                                                                                       HIV/AIDS Medicines       1.00      1.00      1.00         4
#                                                                                                                    Rural Health Concerns       1.00      1.00      1.00         3
#                                                                                                                          Skin Conditions       1.00      1.00      1.00         2
#                                                                                                                          Penis Disorders       1.00      1.00      1.00         7
#                                                                                                                                    Mumps       1.00      1.00      1.00         4
#                                                                                                                                 Syphilis       1.00      1.00      1.00         3
#                                                                                                                               Club Drugs       1.00      1.00      1.00        10
#                                                                                                                        Newborn Screening       1.00      1.00      1.00         5
#                                                                                                                                Emphysema       1.00      1.00      1.00         2
#                                                                                                                                  Surgery       1.00      1.00      1.00         4
#                                                                                                                       Ulcerative Colitis       1.00      0.67      0.80         3
#                                                                                                                               Gallstones       1.00      1.00      1.00         8
#                                                                                                                      Childbirth Problems       1.00      1.00      1.00         6
#                                                                                                                          Palliative Care       1.00      1.00      1.00         4
#                                                                                                                     Financial Assistance       1.00      1.00      1.00         7
#                                                                                                                              Amyloidosis       1.00      1.00      1.00        11
#                                                                                                                           Tubal Ligation       1.00      1.00      1.00        11
#                                                                                                                   Medicines and Children       1.00      1.00      1.00         6
#                                                                                                                        Fungal Infections       1.00      1.00      1.00         4
#                                                                                                                                   Rashes       1.00      1.00      1.00         4
#                                                                                                                             Endocarditis       1.00      1.00      1.00         6
#                                                                                                                               Ultrasound       1.00      1.00      1.00         8
#                                                                                                                               Bedwetting       1.00      1.00      1.00         2
#                                                                                                               Hip Injuries and Disorders       1.00      1.00      1.00         8
#                                                                                                                                Nutrition       0.54      1.00      0.70         7
#                                                                                                                          Hodgkin Disease       1.00      1.00      1.00         5
#                                                                                                                                Pemphigus       1.00      1.00      1.00         6
#                                                                                                                            Endometriosis       1.00      1.00      1.00         3
#                                                                                                                                  Fatigue       1.00      1.00      1.00         3
#                                                                                                       Speech and Communication Disorders       1.00      1.00      1.00         6
#                                                                                                                                Frostbite       1.00      1.00      1.00         8
#                                                                                                                                   Heroin       1.00      1.00      1.00         4
#                                                                                                                     International Health       1.00      1.00      1.00         2
#                                                                                                                     Heart Valve Diseases       1.00      1.00      1.00         6
#                                                                                                                  Diabetic Nerve Problems       1.00      1.00      1.00         3
#                                                                                                                        Blood Count Tests       1.00      1.00      1.00         3
#                                                                                                                Von Hippel-Lindau Disease       0.80      1.00      0.89         4
#                                                                                                                           Organ Donation       1.00      1.00      1.00         7
#                                                                                                           Alpha-1 Antitrypsin Deficiency       0.50      0.50      0.50         2
#                                                                                                                                Pneumonia       1.00      1.00      1.00         5
#                                                                                                                              Hepatitis B       1.00      1.00      1.00         5
#                                                                                                                                    Noise       1.00      1.00      1.00         5
#                                                                                                                            Hiatal Hernia       1.00      1.00      1.00         4
#                                                                                                                      Sprains and Strains       1.00      1.00      1.00         6
#                                                                                                                           Bowel Movement       1.00      1.00      1.00         5
#                                                                                                                                     Coma       1.00      1.00      1.00         5
#                                                                                                                                  Choking       1.00      1.00      1.00         5
#                                                                                                                                 Dwarfism       1.00      1.00      1.00         4
#                                                                                                           Post-Traumatic Stress Disorder       1.00      1.00      1.00         3
#                                                                                                                                   Sodium       1.00      1.00      1.00         5
#                                                                                                                      Lactose Intolerance       0.86      1.00      0.92         6
#                                                                                                                                 Vitiligo       0.00      0.00      0.00         0
#                                                                                                                          Methamphetamine       1.00      1.00      1.00         5
#                                                                                                                   Native American Health       1.00      1.00      1.00         3
#                                                                                                                  Prescription Drug Abuse       1.00      1.00      1.00         4
#                                                                                                                 Cold and Cough Medicines       1.00      1.00      1.00         3
#                                                                                                                             Canker Sores       1.00      1.00      1.00         9
#                                                                                                                                  Measles       1.00      1.00      1.00         7
#                                                                                                                               Stillbirth       1.00      1.00      1.00         3
#                                                                                                                                  Cocaine       1.00      1.00      1.00         6
#                                                                                                                       Metabolic Syndrome       1.00      1.00      1.00         8
#                                                                                                                               Hemophilia       1.00      0.33      0.50         6
#                                                                                                                                 Bursitis       1.00      1.00      1.00         4
#                                                                                                                     Cerebellar Disorders       1.00      1.00      1.00         4
#                                                                                                                          Water Pollution       1.00      1.00      1.00         5
#                                                                                                                     Bacterial Infections       1.00      1.00      1.00         7
#                                                                                                         Clostridium Difficile Infections       1.00      1.00      1.00         7
#                                                                                                                                    Ozone       1.00      1.00      1.00         4
#                                                                                                                     Erectile Dysfunction       1.00      1.00      1.00         3
#                                                                                                                     Chemical Emergencies       1.00      1.00      1.00         3
#                                                                                                                               Tendinitis       1.00      1.00      1.00         5
#                                                                                                                      Cat Scratch Disease       0.50      1.00      0.67         4
#                                                                                                                           Weight Control       1.00      1.00      1.00         5
#                                                                                                                             Bell's Palsy       1.00      0.67      0.80         3
#                                                                                                                                 Jaundice       1.00      1.00      1.00        10
#                                                                                                                                Aneurysms       1.00      1.00      1.00         4
#                                                                                                                                MRI Scans       1.00      1.00      1.00         4
#                                                                                                                           Lead Poisoning       1.00      1.00      1.00        10
#                                                                                                                       Bleeding Disorders       1.00      1.00      1.00         5
#                                                                                                                       Parasitic Diseases       1.00      1.00      1.00         6
#                                                                                                                   Coronavirus Infections       1.00      1.00      1.00         5
#                                                                                                                       Pulmonary Fibrosis       1.00      1.00      1.00         5
#                                                                                                                         Impaired Driving       1.00      1.00      1.00         5
#                                                                                                                             Sun Exposure       1.00      1.00      1.00         3
#                                                                                                                  Pregnancy and Medicines       1.00      1.00      1.00         3
#                                                                                                                          Metabolic Panel       1.00      1.00      1.00         6
#                                                                                                                          Aplastic Anemia       1.00      1.00      1.00         8
#                                                                                                                                Tornadoes       1.00      1.00      1.00         6
#                                                                                                 Attention Deficit Hyperactivity Disorder       1.00      1.00      1.00         9
#                                                                                                                           Mood Disorders       1.00      1.00      1.00        13
#                                                                                                              Degenerative Nerve Diseases       1.00      1.00      1.00         6
# ...
#                                                                                                                          Biliary Atresia       1.00      1.00      1.00         3
#                                                                                                                                Gastritis       1.00      1.00      1.00        10
#                                                                     What I need to know about Preparing for Pregnancy if I Have Diabetes       1.00      1.00      1.00         3
#                                                                                                                       Fecal Incontinence       1.00      1.00      1.00         7
#                                                                                                                      Abdominal Adhesions       1.00      1.00      1.00         6
#                                                                                                                Polycystic Kidney Disease       1.00      0.67      0.80         3
#                                                                             What I need to know about Kidney Failure and How Its Treated       1.00      1.00      1.00         3
#                                                                                                                 Perineal Injury in Males       1.00      1.00      1.00         4
#                                                                                                                           Ectopic Kidney       1.00      1.00      1.00         6
#                                                                                                      Multiple Endocrine Neoplasia Type 1       0.80      1.00      0.89         4
#                                                                                                           Hematuria (Blood in the Urine)       1.00      1.00      1.00         4
#                                                                                                               Urine Blockage in Newborns       1.00      1.00      1.00         2
#                                                                                      What I need to know about Bladder Control for Women       1.00      1.00      1.00         2
#                                                                                                                      Glomerular Diseases       1.00      1.00      1.00         3
#                                                    Am I at Risk for Type 2 Diabetes? Taking Steps to Lower Your Risk of Getting Diabetes       1.00      1.00      1.00         6
#                                                                                                       Insulin Resistance and Prediabetes       1.00      1.00      1.00         5
#                                                                    I Can Lower My Risk for Type 2 Diabetes: A Guide for American Indians       1.00      1.00      1.00         8
#                                                                                                                    Renal Artery Stenosis       1.00      1.00      1.00         4
#                                                                                                           Amyloidosis and Kidney Disease       1.00      1.00      1.00         4
#                                                                                                                Primary Biliary Cirrhosis       1.00      1.00      1.00        10
#                                                                                                                              Proteinuria       1.00      1.00      1.00         5
#                                                                                       Prostate Enlargement: Benign Prostatic Hyperplasia       1.00      1.00      1.00         3
#                                                                                                                         Dumping Syndrome       1.00      1.00      1.00         4
#                                                                                                                   Renal Tubular Acidosis       1.00      1.00      1.00         3
#                                                                                                                         Kidney Dysplasia       1.00      1.00      1.00         5
#                                                                                                                    Viral Gastroenteritis       1.00      1.00      1.00         3
#                                                                                       Prevent diabetes problems: Keep your mouth healthy       1.00      1.00      1.00         4
#                                                                                     Nutrition for Early Chronic Kidney Disease in Adults       1.00      1.00      1.00         2
#                                                                                                    Diagnosis of Diabetes and Prediabetes       1.00      1.00      1.00         9
#                                                                                                        Nerve Disease and Bladder Control       1.00      1.00      1.00         7
#                                                                                                           Kidney Failure: What to Expect       1.00      1.00      1.00         3
#                                                                                                    What I need to know about Hepatitis A       1.00      1.00      1.00         5
#                                                                              Prevent diabetes problems: Keep your diabetes under control       1.00      1.00      1.00         7
#                                                                                                    What I need to know about Hepatitis C       1.00      1.00      1.00         8
# National Hormone and Pituitary Program (NHPP): Information for People Treated with Pituitary Human Growth Hormone (Comprehensive Report)       1.00      1.00      1.00         6
#                                                                                                   High Blood Pressure and Kidney Disease       1.00      1.00      1.00         3
#                                                                                                                     Goodpasture Syndrome       1.00      1.00      1.00         9
#                                                                                        Prevent diabetes problems: Keep your eyes healthy       1.00      1.00      1.00         7
#                                                                                                     Urinary Tract Infections in Children       1.00      1.00      1.00         7
#                                                                              Facing the Challenges of Chronic Kidney Disease in Children       1.00      1.00      1.00         7
#                                                                                                                      Foodborne Illnesses       1.00      1.00      1.00         4
#                                                                                                                  Medullary Sponge Kidney       1.00      1.00      1.00         6
#                                                                                                                          Lupus Nephritis       0.36      1.00      0.53         4
#                                                                 What I need to know about Interstitial Cystitis/Painful Bladder Syndrome       1.00      1.00      1.00         4
#                                                                                           What I need to know about Gestational Diabetes       1.00      1.00      1.00         5
#                                           Dermatitis Herpetiformis: Skin Manifestation of Celiac Disease (For Health Care Professionals)       1.00      1.00      1.00         5
#                                                                                                Your Guide to Diabetes: Type 1 and Type 2       1.00      1.00      1.00         3
#                                                                                                        Urinary Tract Infection In Adults       1.00      1.00      1.00         4
#                                                                                                            Pregnancy and Thyroid Disease       1.00      1.00      1.00         1
#                                                                                                What I need to know about Crohn's Disease       1.00      1.00      1.00         6
#                                                                                                             Chronic Diarrhea in Children       1.00      1.00      1.00         9
#                                                                                                         Anemia in Chronic Kidney Disease       1.00      1.00      1.00         5
#                                                                                                                    Vesicoureteral Reflux       1.00      1.00      1.00         4
#                                                                                                                  Diabetic Kidney Disease       1.00      1.00      1.00         5
#                                                                                                    Hemolytic Uremic Syndrome in Children       1.00      1.00      1.00         6
#                                                                                                               Zollinger-Ellison Syndrome       1.00      1.00      1.00         8
#                                                                                                                                Cystocele       1.00      1.00      1.00         5
#                                                                                                                          Inguinal Hernia       1.00      1.00      1.00         4
#                                                                                     What I need to know about Living with Kidney Failure       1.00      1.00      1.00         4
#                                                                                                       What I need to know about Diarrhea       1.00      1.00      1.00         4
#                                                                                                  Viral Hepatitis: A through E and Beyond       1.00      1.00      1.00         6
#                                                                                                             Nonalcoholic Steatohepatitis       1.00      0.33      0.50         6
#                                                                                                               Your Diabetes Care Records       1.00      1.00      1.00         5
#                                                                                                                  Henoch-Schnlein Purpura       1.00      1.00      1.00         5
#                                                                                                             Childhood Nephrotic Syndrome       1.00      1.00      1.00         5
#                                                                                                                         Mntriers Disease       1.00      1.00      1.00         3
#                                                                                                                     Diverticular Disease       1.00      1.00      1.00         6
#                                                                         Microscopic Colitis: Collagenous Colitis and Lymphocytic Colitis       1.00      1.00      1.00         4
#                                                                                                                 Cyclic Vomiting Syndrome       1.00      0.67      0.80         3
#                                                                                      Diabetic Neuropathies: The Nerve Damage of Diabetes       1.00      1.00      1.00         6
#
#                                                                                                                                 accuracy                           0.97     27168
#                                                                                                                                macro avg       0.97      0.97      0.96     27168
#                                                                                                                             weighted avg       0.98      0.97      0.97     27168
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
num_classes = data['focus_area'].nunique()
print("Number of unique classes:", num_classes)
# Out:
# Number of unique classes: 5126
